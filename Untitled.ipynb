# %%
import pandas as pd

# %%
csv_path = "recruitment_data.csv"
df = pd.read_csv(csv_path)
df.head()
# Out:
#    Age  Gender  EducationLevel  ExperienceYears  PreviousCompanies  \
# 0   26       1               2                0                  3
# 1   39       1               4               12                  3
# 2   48       0               2                3                  2
# 3   34       1               2                5                  2
# 4   30       0               1                6                  1
#
#    DistanceFromCompany  InterviewScore  SkillScore  PersonalityScore  \
# 0            26.783828              48          78                91
# 1            25.862694              35          68                80
# 2             9.920805              20          67                13
# 3             6.407751              36          27                70
# 4            43.105343              23          52                85
#
#    RecruitmentStrategy  HiringDecision
# 0                    1               1
# 1                    2               1
# ...

# %%
X = df.drop(labels=['HiringDecision'],axis=1) #tabela de dados
y= df['HiringDecision'] #tabela de resultados(labels) para a decision tree

# %%
X.head(5)
# Out:
#    Age  Gender  EducationLevel  ExperienceYears  PreviousCompanies  \
# 0   26       1               2                0                  3
# 1   39       1               4               12                  3
# 2   48       0               2                3                  2
# 3   34       1               2                5                  2
# 4   30       0               1                6                  1
#
#    DistanceFromCompany  InterviewScore  SkillScore  PersonalityScore  \
# 0            26.783828              48          78                91
# 1            25.862694              35          68                80
# 2             9.920805              20          67                13
# 3             6.407751              36          27                70
# 4            43.105343              23          52                85
#
#    RecruitmentStrategy
# 0                    1
# 1                    2
# 2                    2
# 3                    3
# 4                    2
